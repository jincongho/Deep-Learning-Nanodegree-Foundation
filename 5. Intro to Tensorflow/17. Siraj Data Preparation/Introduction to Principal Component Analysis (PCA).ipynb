# %%
import numpy as np
np.random.seed(1)

# %%
sample_mean = np.array([0,0,0])
sample_con  = np.array([[1,0,0], [0,1,0], [0,0,1]])

class1 = np.random.multivariate_normal(sample_mean, sample_con, 20).T
print(class1)
# Out:
# [[-1.27255876  1.29322588  0.5627611  -0.0731127   1.90465871 -1.62743834
#    0.81095167  0.82400562 -1.33195167 -0.89055558 -0.3264995  -0.58652394
#    0.62336218  0.12910158  1.55880554  2.44936865 -0.7003985   0.20183018
#   -0.12046457 -0.66575452]
#  [ 0.31354772 -0.11044703  0.24073709  1.16033857  1.1110567   0.60231928
#    1.04444209 -0.56230543 -1.76068856 -1.1191154  -1.34267579 -1.23685338
#   -0.43495668  1.6169496   0.1094027  -0.54577417 -0.20339445  0.66102029
#   -1.23312074 -1.67419581]
#  [ 0.50318481 -0.61736206  0.28066508  0.36949272  0.6590498   0.4202822
#   -0.40087819  1.95487808 -1.65072127  1.9560789   1.11438298  0.87583893
#    1.40754     0.50274088 -1.2197444  -0.19883786  0.24266944  1.79215821
#   -1.18231813  0.82502982]]

# %%
sample_mean = np.array([1,1,1])
sample_con  = np.array([[1,0,0], [0,1,0], [0,0,1]])

class2 = np.random.multivariate_normal(sample_mean, sample_con, 20).T
print(class1)
# Out:
# [[-1.27255876  1.29322588  0.5627611  -0.0731127   1.90465871 -1.62743834
#    0.81095167  0.82400562 -1.33195167 -0.89055558 -0.3264995  -0.58652394
#    0.62336218  0.12910158  1.55880554  2.44936865 -0.7003985   0.20183018
#   -0.12046457 -0.66575452]
#  [ 0.31354772 -0.11044703  0.24073709  1.16033857  1.1110567   0.60231928
#    1.04444209 -0.56230543 -1.76068856 -1.1191154  -1.34267579 -1.23685338
#   -0.43495668  1.6169496   0.1094027  -0.54577417 -0.20339445  0.66102029
#   -1.23312074 -1.67419581]
#  [ 0.50318481 -0.61736206  0.28066508  0.36949272  0.6590498   0.4202822
#   -0.40087819  1.95487808 -1.65072127  1.9560789   1.11438298  0.87583893
#    1.40754     0.50274088 -1.2197444  -0.19883786  0.24266944  1.79215821
#   -1.18231813  0.82502982]]

# %%
# %pylab inline

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10

ax.plot(class1[0,:], class1[1,:], class1[2,:], 'o', markersize=8, 
        color='blue', alpha=0.5, label='class1')
ax.plot(class2[0,:], class2[1,:], class2[2,:], '^', markersize=8, 
        color='green', alpha=0.5, label='class2')

ax.legend(loc='upper right')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = np.concatenate((class1, class2), axis=1)
print(dataset)
# Out:
# [[-1.27255876  1.29322588  0.5627611  -0.0731127   1.90465871 -1.62743834
#    0.81095167  0.82400562 -1.33195167 -0.89055558 -0.3264995  -0.58652394
#    0.62336218  0.12910158  1.55880554  2.44936865 -0.7003985   0.20183018
#   -0.12046457 -0.66575452  0.50178644 -0.39662042  1.61853913 -0.30572692
#   -1.793085   -0.04458938  1.42952614 -0.52568032  1.1340482   1.26246745
#    1.83600472  1.88490881 -0.44087602  2.39984394  1.09542509  1.21112476
#   -0.11647002  0.94317552  0.91549197  1.78477065]
#  [ 0.31354772 -0.11044703  0.24073709  1.16033857  1.1110567   0.60231928
#    1.04444209 -0.56230543 -1.76068856 -1.1191154  -1.34267579 -1.23685338
#   -0.43495668  1.6169496   0.1094027  -0.54577417 -0.20339445  0.66102029
#   -1.23312074 -1.67419581  0.68901502  0.13868364  0.55682807  0.65501279
#    2.93752881  3.05117344  0.3930016   1.79502609  2.20205486  1.2764993
#    2.54335911  0.12271848  2.23225307  0.21808832  1.92145007  1.01652757
#    1.0809271   1.49233656  0.70263812  0.04457474]
#  [ 0.50318481 -0.61736206  0.28066508  0.36949272  0.6590498   0.4202822
#   -0.40087819  1.95487808 -1.65072127  1.9560789   1.11438298  0.87583893
#    1.40754     0.50274088 -1.2197444  -0.19883786  0.24266944  1.79215821
#   -1.18231813  0.82502982  0.99810852  1.67471153  2.81053491  0.76916026
#    1.36633201  1.585662    1.10622272  0.62556168  1.28474811  0.2667284
#    1.75880566  0.13221278  0.74582013  0.56249102  1.0607502   1.17718772
#    0.81342101  0.31932186  1.417302    1.58591043]]

# %%
mean_x = np.mean(dataset[0,:])
mean_y = np.mean(dataset[1,:])
mean_z = np.mean(dataset[2,:])

mean_vector = np.array([[mean_x], [mean_y], [mean_z]])
print('Mean vector: \n', mean_vector)
# Out:
# Mean vector:
#  [[ 0.42892194]
#  [ 0.54264958]
#  [ 0.74237807]]

# %%
cov_mat = np.cov([dataset[0,:], dataset[1,:], dataset[2,:]])
print('Covariance Matrix:\n', cov_mat)
# Out:
# Covariance Matrix:
#  [[ 1.24921068  0.14436369  0.04687003]
#  [ 0.14436369  1.47431766  0.31033639]
#  [ 0.04687003  0.31033639  0.84256265]]

# %%
eigen_val, eigen_vec = np.linalg.eig(cov_mat)

for i in range(len(eigen_val)):
    eigvec_sc = eigen_vec[:,i].reshape(1,3).T
    print('Eigenvector {}: \n{}'.format(i+1, eigvec_sc))
    print('Eigenvalue {} from scatter matrix: {}'.format(i+1, eigen_val[i]))
# Out:
# [[ 0.34777607  0.93731505  0.02218791]
#  [ 0.86935525 -0.31351791 -0.3820052 ]
#  [ 0.35110292 -0.15214144  0.92389378]]
# Eigenvector 1:
# [[ 0.34777607]
#  [ 0.86935525]
#  [ 0.35110292]]
# Eigenvalue 1 from scatter matrix: 1.6574030519389114
# Eigenvector 2:
# [[ 0.93731505]
#  [-0.31351791]
#  [-0.15214144]]
# Eigenvalue 2 from scatter matrix: 1.1933154114848328
# Eigenvector 3:
# [[ 0.02218791]
#  [-0.3820052 ]
#  [ 0.92389378]]
# Eigenvalue 3 from scatter matrix: 0.7153725215615573

# %%
eigen_pairs = [(np.abs(eigen_val[i]), eigen_vec[:,i]) 
               for i in range(len(eigen_val))]
eigen_pairs.sort()
eigen_pairs.reverse()

print(eigen_pairs)
for i in eigen_pairs:
    print(i[0])
# Out:
# [(1.6574030519389114, array([ 0.34777607,  0.86935525,  0.35110292])), (1.1933154114848328, array([ 0.93731505, -0.31351791, -0.15214144])), (0.71537252156155728, array([ 0.02218791, -0.3820052 ,  0.92389378]))]
# 1.65740305194
# 1.19331541148
# 0.715372521562

# %%
matrix_w = np.hstack((eigen_pairs[0][1].reshape(3,1),
                    eigen_pairs[1][1].reshape(3,1)))
print('Matrix W:\n', matrix_w)
# Out:
# Matrix W:
#  [[ 0.34777607  0.93731505]
#  [ 0.86935525 -0.31351791]
#  [ 0.35110292 -0.15214144]]

# %%
transformed = matrix_w.T.dot(dataset)
assert transformed.shape == (2,40)

# %%
plt.plot(transformed[0, 0:20], trasnformed[1,0:20],
        'o', markersize=7, color='green', alpha=0.5, label='class1')
plt.plot(transformed[0, 20:40], transformed[1, 20:40],
        '^', markersize=7, color='red', alpha=0.5, label='class2')
plt.xlim([-5,5])
plt.ylim([-5,5])
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.legend()
plt.title('Transformed samples with class labels')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1786150116c1> in <module>()
# ----> 1 plt.plot(transformed[0, 0:20], trasnformed[1,0:20],
#       2         'o', markersize=7, color='green', alpha=0.5, label='class1')
#       3 plt.plot(transformed[0, 20:40], transformed[1, 20:40],
#       4         '^', markersize=7, color='red', alpha=0.5, label='class2')
#       5 plt.xlim([-5,5])
#
# NameError: name 'trasnformed' is not defined
